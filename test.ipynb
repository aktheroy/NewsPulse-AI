# %%
import requests
from bs4 import BeautifulSoup
from newspaper import Article, Config
import time
import re
import json
from textblob import TextBlob
import yake
from gtts import gTTS
from deep_translator import GoogleTranslator
import os

class NewsAnalyzer:
    def __init__(self, company_name: str):
        self.company_name = company_name
        self.articles = []
        self.summarized_articles = []
        self.sentiment_distribution = {"Positive": 0, "Negative": 0, "Neutral": 0}
        
        # Newspaper3k configuration
        self.config = Config()
        self.config.request_timeout = 10
        self.config.browser_user_agent = (
            "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
            "AppleWebKit/537.36 (KHTML, like Gecko) "
            "Chrome/89.0.4389.82 Safari/537.36"
        )
        
        # YAKE keyword extractor
        self.kw_extractor = yake.KeywordExtractor(lan="en", n=1, top=3)

    def scrape_news(self):
        """Main method to perform complete news scraping and analysis"""
        self._scrape_articles()
        self._process_articles()
        return self.generate_report()

    def _search_news(self) -> List[str]:
        """Search DuckDuckGo for news articles"""
        base_url = "https://duckduckgo.com/html/"
        params = {"q": f"{self.company_name} news", "kl": "us-en"}
        headers = {
            "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
            "AppleWebKit/537.36 (KHTML, like Gecko) "
            "Chrome/91.0.4472.124 Safari/537.36"
        }

        try:
            response = requests.get(base_url, headers=headers, params=params)
            response.raise_for_status()
            soup = BeautifulSoup(response.text, 'html.parser')
            urls = set()

            for link in soup.select("a.result__a"):
                href = link.get("href", "")
                if match := re.search(r"(https?://[^\s\"']+)", href):
                    url = match.group(1)
                    if "duckduckgo.com" not in url:
                        urls.add(url)

            return list(urls)[:10]

        except requests.RequestException as e:
            print(f"Search failed: {str(e)}")
            return []

    def _scrape_article(self, url: str) -> Dict:
        """Scrape individual article content"""
        article = Article(url, config=self.config)
        try:
            article.download()
            article.parse()
            article.nlp()
            return {
                "title": article.title,
                "summary": article.summary,
                "full_text": article.text,
                "url": url,
                "date": article.publish_date.strftime("%Y-%m-%d") if article.publish_date else None,
                "keywords": article.keywords,
                "authors": article.authors
            }
        except Exception as e:
            print(f"Scraping failed for {url}: {str(e)}")
            return {}

    def _scrape_articles(self):
        """Scrape and store articles"""
        urls = self._search_news()
        for url in urls:
            if article := self._scrape_article(url):
                self.articles.append(article)
                time.sleep(2)
        self.articles = self.articles[:10]

    def _analyze_sentiment(self, text: str) -> str:
        """Determine text sentiment"""
        analysis = TextBlob(text)
        if analysis.sentiment.polarity > 0.1:
            return "Positive"
        elif analysis.sentiment.polarity < -0.1:
            return "Negative"
        return "Neutral"

    def _process_articles(self):
        """Process all scraped articles for sentiment and topics"""
        for article in self.articles:
            title = article.get("title", "No Title")
            summary = article.get("summary", "No Summary")
            sentiment = self._analyze_sentiment(summary)
            topics = [kw[0] for kw in self.kw_extractor.extract_keywords(summary)]

            self.sentiment_distribution[sentiment] += 1
            self.summarized_articles.append({
                "Title": title,
                "Summary": summary,
                "Sentiment": sentiment,
                "Topics": topics
            })

    def _generate_comparisons(self) -> tuple:
        """Generate article comparisons and topic analysis"""
        comparisons = []
        for i in range(len(self.summarized_articles) - 1):
            for j in range(i + 1, len(self.summarized_articles)):
                art1 = self.summarized_articles[i]
                art2 = self.summarized_articles[j]
                comparisons.append({
                    "Comparison": f"{art1['Title']} vs {art2['Title']}",
                    "Sentiment": f"{art1['Sentiment']} vs {art2['Sentiment']}",
                    "Topics": f"{art1['Topics']} vs {art2['Topics']}"
                })

        topics = [set(art["Topics"]) for art in self.summarized_articles]
        common_topics = set.intersection(*topics) if topics else []
        return comparisons, {
            "common_topics": list(common_topics),
            "unique_topics": {art["Title"]: art["Topics"] for art in self.summarized_articles}
        }

    def _generate_hindi_audio(self, text: str) -> str:
        """Generate Hindi audio from text"""
        try:
            translated = GoogleTranslator(source='auto', target='hi').translate(text)
            tts = gTTS(translated, lang='hi')
            filename = f"{self.company_name}_summary.mp3"
            tts.save(filename)
            return filename
        except Exception as e:
            print(f"Audio generation error: {str(e)}")
            return ""

    def generate_report(self) -> Dict:
        """Generate final analysis report with audio"""
        total_articles = len(self.summarized_articles)
        comparisons, topics = self._generate_comparisons()
        
        # Generate summary text
        sentiment_text = (f"Found {total_articles} articles. "
                         f"Positive: {self.sentiment_distribution['Positive']}, "
                         f"Negative: {self.sentiment_distribution['Negative']}, "
                         f"Neutral: {self.sentiment_distribution['Neutral']}.")

        # Generate audio
        audio_file = self._generate_hindi_audio(sentiment_text)

        return {
            "company": self.company_name,
            "summary": sentiment_text,
            "sentiment_distribution": self.sentiment_distribution,
            "comparative_analysis": comparisons,
            "topic_analysis": topics,
            "audio_file": audio_file,
            "articles": self.summarized_articles
        }

# Example usage
if __name__ == "__main__":
    analyzer = NewsAnalyzer("Tesla")
    report = analyzer.scrape_news()
    
    print(json.dumps(report, indent=4))
    
    # Play audio summary
    if report['audio_file']:
        os.system(f"start {report['audio_file']}")
# Out:
# {
#     "company": "Tesla",
#     "summary": "Found 10 articles. Positive: 3, Negative: 1, Neutral: 6.",
#     "sentiment_distribution": {
#         "Positive": 3,
#         "Negative": 1,
#         "Neutral": 6
#     },
#     "comparative_analysis": [
#         {
#             "Comparison": "Electrek vs Tesla News, Tips, Rumors, and Reviews",
#             "Sentiment": "Neutral vs Neutral",
#             "Topics": "['car', 'Tesla', 'market'] vs ['Tesla', 'yearsThe', 'departure']"
#         },
#         {
#             "Comparison": "Electrek vs Tesla News Articles and Press Releases",
#             "Sentiment": "Neutral vs Neutral",
#             "Topics": "['car', 'Tesla', 'market'] vs []"
#         },
#         {
#             "Comparison": "Electrek vs Tesla, Inc. (TSLA) Latest Stock News & Headlines",
#             "Sentiment": "Neutral vs Positive",
#             "Topics": "['car', 'Tesla', 'market'] vs ['TSLA', 'NASDAQ', 'Stock']"
#         },
#         {
#             "Comparison": "Electrek vs Tesla News Source",
#             "Sentiment": "Neutral vs Negative",
#             "Topics": "['car', 'Tesla', 'market'] vs ['Tesla', 'elonmusk', 'pushback']"
#         },
#         {
#             "Comparison": "Electrek vs Tesla\u2019s next-generation vehicle: all the news about Elon Musk\u2019s next big EV bet",
#             "Sentiment": "Neutral vs Positive",
#             "Topics": "['car', 'Tesla', 'market'] vs ['Tesla', 'CEO', 'Elon']"
#         },
#         {
#             "Comparison": "Electrek vs Plummeting stock, boycotts and flagging sales: What's fueling turmoil for Tesla?",
#             "Sentiment": "Neutral vs Neutral",
#             "Topics": "['car', 'Tesla', 'market'] vs ['BYD', 'Tesla', 'Chinese']"
#         },
#         {
#             "Comparison": "Electrek vs Latest Tesla News",
#             "Sentiment": "Neutral vs Neutral",
#             "Topics": "['car', 'Tesla', 'market'] vs ['Trump', 'excluded', 'Canada']"
#         },
#         {
#             "Comparison": "Electrek vs Tesla board members, executive sell off over $100 million of stock in recent weeks",
#             "Sentiment": "Neutral vs Neutral",
#             "Topics": "['car', 'Tesla', 'market'] vs ['February', 'Tesla', 'million']"
#         },
#         {
#             "Comparison": "Electrek vs Hundreds gather outside Tesla showrooms in backlash to Elon Musk\u2019s role with DOGE",
#             "Sentiment": "Neutral vs Positive",
#             "Topics": "['car', 'Tesla', 'market'] vs ['Tesla', 'Takedown', 'February']"
#         },
#         {
#             "Comparison": "Tesla News, Tips, Rumors, and Reviews vs Tesla News Articles and Press Releases",
#             "Sentiment": "Neutral vs Neutral",
#             "Topics": "['Tesla', 'yearsThe', 'departure'] vs []"
#         },
#         {
#             "Comparison": "Tesla News, Tips, Rumors, and Reviews vs Tesla, Inc. (TSLA) Latest Stock News & Headlines",
#             "Sentiment": "Neutral vs Positive",
#             "Topics": "['Tesla', 'yearsThe', 'departure'] vs ['TSLA', 'NASDAQ', 'Stock']"
#         },
#         {
#             "Comparison": "Tesla News, Tips, Rumors, and Reviews vs Tesla News Source",
#             "Sentiment": "Neutral vs Negative",
#             "Topics": "['Tesla', 'yearsThe', 'departure'] vs ['Tesla', 'elonmusk', 'pushback']"
#         },
#         {
#             "Comparison": "Tesla News, Tips, Rumors, and Reviews vs Tesla\u2019s next-generation vehicle: all the news about Elon Musk\u2019s next big EV bet",
#             "Sentiment": "Neutral vs Positive",
#             "Topics": "['Tesla', 'yearsThe', 'departure'] vs ['Tesla', 'CEO', 'Elon']"
#         },
#         {
#             "Comparison": "Tesla News, Tips, Rumors, and Reviews vs Plummeting stock, boycotts and flagging sales: What's fueling turmoil for Tesla?",
#             "Sentiment": "Neutral vs Neutral",
#             "Topics": "['Tesla', 'yearsThe', 'departure'] vs ['BYD', 'Tesla', 'Chinese']"
#         },
#         {
#             "Comparison": "Tesla News, Tips, Rumors, and Reviews vs Latest Tesla News",
#             "Sentiment": "Neutral vs Neutral",
#             "Topics": "['Tesla', 'yearsThe', 'departure'] vs ['Trump', 'excluded', 'Canada']"
#         },
#         {
#             "Comparison": "Tesla News, Tips, Rumors, and Reviews vs Tesla board members, executive sell off over $100 million of stock in recent weeks",
#             "Sentiment": "Neutral vs Neutral",
#             "Topics": "['Tesla', 'yearsThe', 'departure'] vs ['February', 'Tesla', 'million']"
#         },
#         {
#             "Comparison": "Tesla News, Tips, Rumors, and Reviews vs Hundreds gather outside Tesla showrooms in backlash to Elon Musk\u2019s role with DOGE",
#             "Sentiment": "Neutral vs Positive",
#             "Topics": "['Tesla', 'yearsThe', 'departure'] vs ['Tesla', 'Takedown', 'February']"
#         },
#         {
#             "Comparison": "Tesla News Articles and Press Releases vs Tesla, Inc. (TSLA) Latest Stock News & Headlines",
#             "Sentiment": "Neutral vs Positive",
#             "Topics": "[] vs ['TSLA', 'NASDAQ', 'Stock']"
#         },
#         {
#             "Comparison": "Tesla News Articles and Press Releases vs Tesla News Source",
#             "Sentiment": "Neutral vs Negative",
#             "Topics": "[] vs ['Tesla', 'elonmusk', 'pushback']"
#         },
#         {
#             "Comparison": "Tesla News Articles and Press Releases vs Tesla\u2019s next-generation vehicle: all the news about Elon Musk\u2019s next big EV bet",
#             "Sentiment": "Neutral vs Positive",
#             "Topics": "[] vs ['Tesla', 'CEO', 'Elon']"
#         },
#         {
#             "Comparison": "Tesla News Articles and Press Releases vs Plummeting stock, boycotts and flagging sales: What's fueling turmoil for Tesla?",
#             "Sentiment": "Neutral vs Neutral",
#             "Topics": "[] vs ['BYD', 'Tesla', 'Chinese']"
#         },
#         {
#             "Comparison": "Tesla News Articles and Press Releases vs Latest Tesla News",
#             "Sentiment": "Neutral vs Neutral",
#             "Topics": "[] vs ['Trump', 'excluded', 'Canada']"
#         },
#         {
#             "Comparison": "Tesla News Articles and Press Releases vs Tesla board members, executive sell off over $100 million of stock in recent weeks",
#             "Sentiment": "Neutral vs Neutral",
#             "Topics": "[] vs ['February', 'Tesla', 'million']"
#         },
#         {
#             "Comparison": "Tesla News Articles and Press Releases vs Hundreds gather outside Tesla showrooms in backlash to Elon Musk\u2019s role with DOGE",
#             "Sentiment": "Neutral vs Positive",
#             "Topics": "[] vs ['Tesla', 'Takedown', 'February']"
#         },
#         {
#             "Comparison": "Tesla, Inc. (TSLA) Latest Stock News & Headlines vs Tesla News Source",
#             "Sentiment": "Positive vs Negative",
#             "Topics": "['TSLA', 'NASDAQ', 'Stock'] vs ['Tesla', 'elonmusk', 'pushback']"
#         },
#         {
#             "Comparison": "Tesla, Inc. (TSLA) Latest Stock News & Headlines vs Tesla\u2019s next-generation vehicle: all the news about Elon Musk\u2019s next big EV bet",
#             "Sentiment": "Positive vs Positive",
#             "Topics": "['TSLA', 'NASDAQ', 'Stock'] vs ['Tesla', 'CEO', 'Elon']"
#         },
#         {
#             "Comparison": "Tesla, Inc. (TSLA) Latest Stock News & Headlines vs Plummeting stock, boycotts and flagging sales: What's fueling turmoil for Tesla?",
#             "Sentiment": "Positive vs Neutral",
#             "Topics": "['TSLA', 'NASDAQ', 'Stock'] vs ['BYD', 'Tesla', 'Chinese']"
#         },
#         {
#             "Comparison": "Tesla, Inc. (TSLA) Latest Stock News & Headlines vs Latest Tesla News",
#             "Sentiment": "Positive vs Neutral",
#             "Topics": "['TSLA', 'NASDAQ', 'Stock'] vs ['Trump', 'excluded', 'Canada']"
#         },
#         {
#             "Comparison": "Tesla, Inc. (TSLA) Latest Stock News & Headlines vs Tesla board members, executive sell off over $100 million of stock in recent weeks",
#             "Sentiment": "Positive vs Neutral",
#             "Topics": "['TSLA', 'NASDAQ', 'Stock'] vs ['February', 'Tesla', 'million']"
#         },
#         {
#             "Comparison": "Tesla, Inc. (TSLA) Latest Stock News & Headlines vs Hundreds gather outside Tesla showrooms in backlash to Elon Musk\u2019s role with DOGE",
#             "Sentiment": "Positive vs Positive",
#             "Topics": "['TSLA', 'NASDAQ', 'Stock'] vs ['Tesla', 'Takedown', 'February']"
#         },
#         {
#             "Comparison": "Tesla News Source vs Tesla\u2019s next-generation vehicle: all the news about Elon Musk\u2019s next big EV bet",
#             "Sentiment": "Negative vs Positive",
#             "Topics": "['Tesla', 'elonmusk', 'pushback'] vs ['Tesla', 'CEO', 'Elon']"
#         },
#         {
#             "Comparison": "Tesla News Source vs Plummeting stock, boycotts and flagging sales: What's fueling turmoil for Tesla?",
#             "Sentiment": "Negative vs Neutral",
#             "Topics": "['Tesla', 'elonmusk', 'pushback'] vs ['BYD', 'Tesla', 'Chinese']"
#         },
#         {
#             "Comparison": "Tesla News Source vs Latest Tesla News",
#             "Sentiment": "Negative vs Neutral",
#             "Topics": "['Tesla', 'elonmusk', 'pushback'] vs ['Trump', 'excluded', 'Canada']"
#         },
#         {
#             "Comparison": "Tesla News Source vs Tesla board members, executive sell off over $100 million of stock in recent weeks",
#             "Sentiment": "Negative vs Neutral",
#             "Topics": "['Tesla', 'elonmusk', 'pushback'] vs ['February', 'Tesla', 'million']"
#         },
#         {
#             "Comparison": "Tesla News Source vs Hundreds gather outside Tesla showrooms in backlash to Elon Musk\u2019s role with DOGE",
#             "Sentiment": "Negative vs Positive",
#             "Topics": "['Tesla', 'elonmusk', 'pushback'] vs ['Tesla', 'Takedown', 'February']"
#         },
#         {
#             "Comparison": "Tesla\u2019s next-generation vehicle: all the news about Elon Musk\u2019s next big EV bet vs Plummeting stock, boycotts and flagging sales: What's fueling turmoil for Tesla?",
#             "Sentiment": "Positive vs Neutral",
#             "Topics": "['Tesla', 'CEO', 'Elon'] vs ['BYD', 'Tesla', 'Chinese']"
#         },
#         {
#             "Comparison": "Tesla\u2019s next-generation vehicle: all the news about Elon Musk\u2019s next big EV bet vs Latest Tesla News",
#             "Sentiment": "Positive vs Neutral",
#             "Topics": "['Tesla', 'CEO', 'Elon'] vs ['Trump', 'excluded', 'Canada']"
#         },
#         {
#             "Comparison": "Tesla\u2019s next-generation vehicle: all the news about Elon Musk\u2019s next big EV bet vs Tesla board members, executive sell off over $100 million of stock in recent weeks",
#             "Sentiment": "Positive vs Neutral",
#             "Topics": "['Tesla', 'CEO', 'Elon'] vs ['February', 'Tesla', 'million']"
#         },
#         {
#             "Comparison": "Tesla\u2019s next-generation vehicle: all the news about Elon Musk\u2019s next big EV bet vs Hundreds gather outside Tesla showrooms in backlash to Elon Musk\u2019s role with DOGE",
#             "Sentiment": "Positive vs Positive",
#             "Topics": "['Tesla', 'CEO', 'Elon'] vs ['Tesla', 'Takedown', 'February']"
#         },
#         {
#             "Comparison": "Plummeting stock, boycotts and flagging sales: What's fueling turmoil for Tesla? vs Latest Tesla News",
#             "Sentiment": "Neutral vs Neutral",
#             "Topics": "['BYD', 'Tesla', 'Chinese'] vs ['Trump', 'excluded', 'Canada']"
#         },
#         {
#             "Comparison": "Plummeting stock, boycotts and flagging sales: What's fueling turmoil for Tesla? vs Tesla board members, executive sell off over $100 million of stock in recent weeks",
#             "Sentiment": "Neutral vs Neutral",
#             "Topics": "['BYD', 'Tesla', 'Chinese'] vs ['February', 'Tesla', 'million']"
#         },
#         {
#             "Comparison": "Plummeting stock, boycotts and flagging sales: What's fueling turmoil for Tesla? vs Hundreds gather outside Tesla showrooms in backlash to Elon Musk\u2019s role with DOGE",
#             "Sentiment": "Neutral vs Positive",
#             "Topics": "['BYD', 'Tesla', 'Chinese'] vs ['Tesla', 'Takedown', 'February']"
#         },
#         {
#             "Comparison": "Latest Tesla News vs Tesla board members, executive sell off over $100 million of stock in recent weeks",
#             "Sentiment": "Neutral vs Neutral",
#             "Topics": "['Trump', 'excluded', 'Canada'] vs ['February', 'Tesla', 'million']"
#         },
#         {
#             "Comparison": "Latest Tesla News vs Hundreds gather outside Tesla showrooms in backlash to Elon Musk\u2019s role with DOGE",
#             "Sentiment": "Neutral vs Positive",
#             "Topics": "['Trump', 'excluded', 'Canada'] vs ['Tesla', 'Takedown', 'February']"
#         },
#         {
#             "Comparison": "Tesla board members, executive sell off over $100 million of stock in recent weeks vs Hundreds gather outside Tesla showrooms in backlash to Elon Musk\u2019s role with DOGE",
#             "Sentiment": "Neutral vs Positive",
#             "Topics": "['February', 'Tesla', 'million'] vs ['Tesla', 'Takedown', 'February']"
#         }
#     ],
#     "topic_analysis": {
#         "common_topics": [],
#         "unique_topics": {
#             "Electrek": [
#                 "car",
#                 "Tesla",
#                 "market"
#             ],
#             "Tesla News, Tips, Rumors, and Reviews": [
#                 "Tesla",
#                 "yearsThe",
#                 "departure"
#             ],
#             "Tesla News Articles and Press Releases": [],
#             "Tesla, Inc. (TSLA) Latest Stock News & Headlines": [
#                 "TSLA",
#                 "NASDAQ",
#                 "Stock"
#             ],
#             "Tesla News Source": [
#                 "Tesla",
#                 "elonmusk",
#                 "pushback"
#             ],
#             "Tesla\u2019s next-generation vehicle: all the news about Elon Musk\u2019s next big EV bet": [
#                 "Tesla",
#                 "CEO",
#                 "Elon"
#             ],
#             "Plummeting stock, boycotts and flagging sales: What's fueling turmoil for Tesla?": [
#                 "BYD",
#                 "Tesla",
#                 "Chinese"
#             ],
#             "Latest Tesla News": [
#                 "Trump",
#                 "excluded",
#                 "Canada"
#             ],
#             "Tesla board members, executive sell off over $100 million of stock in recent weeks": [
#                 "February",
#                 "Tesla",
#                 "million"
#             ],
#             "Hundreds gather outside Tesla showrooms in backlash to Elon Musk\u2019s role with DOGE": [
#                 "Tesla",
#                 "Takedown",
#                 "February"
#             ]
#         }
#     },
#     "audio_file": "Tesla_summary.mp3",
#     "articles": [
#         {
#             "Title": "Electrek",
#             "Summary": "Tesla used car prices are falling at three times the rate of the rest of the used car market, which is also going down.\nWhen new sales and used sales are not going well, it\u2019s a giant red flag.\nExpandExpandingClose",
#             "Sentiment": "Neutral",
#             "Topics": [
#                 "car",
#                 "Tesla",
#                 "market"
#             ]
#         },
#         {
#             "Title": "Tesla News, Tips, Rumors, and Reviews",
#             "Summary": "This Tesla safety engineer just left after over 14 yearsThe crash engineer didn't disclose any specific reasons for his departure.\n\"I have decided now is the time to move on.\"",
#             "Sentiment": "Neutral",
#             "Topics": [
#                 "Tesla",
#                 "yearsThe",
#                 "departure"
#             ]
#         },
#         {
#             "Title": "Tesla News Articles and Press Releases",
#             "Summary": "",
#             "Sentiment": "Neutral",
#             "Topics": []
#         },
#         {
#             "Title": "Tesla, Inc. (TSLA) Latest Stock News & Headlines",
#             "Summary": "Tesla (TSLA) Stock Trades Down, Here Is WhyShares of electric vehicle pioneer Tesla (NASDAQ:TSLA) fell 6.3% in the morning session after the EV battle in China continued to heat up as BYD announced its new \"Super e-Platform,\" a technology it claimed could charge electric vehicles in just five minutes.\nThe company added that the new technology had a peak charging speed of 1,000 kilowatts.\nTo put it in perspective, Tesla's latest superchargers maxed out at 500 kilowatts (at the time BYD announced the Super e-Platform), so BYD's tech would",
#             "Sentiment": "Positive",
#             "Topics": [
#                 "TSLA",
#                 "NASDAQ",
#                 "Stock"
#             ]
#         },
#         {
#             "Title": "Tesla News Source",
#             "Summary": "\ud83d\udea8 Does all the pushback and hate against @Tesla and @elonmusk make you want to support them both more?\nhttps://t.co/9eudCDccUo pic.twitter.com/irUyfzHV86",
#             "Sentiment": "Negative",
#             "Topics": [
#                 "Tesla",
#                 "elonmusk",
#                 "pushback"
#             ]
#         },
#         {
#             "Title": "Tesla\u2019s next-generation vehicle: all the news about Elon Musk\u2019s next big EV bet",
#             "Summary": "For years, Tesla CEO Elon Musk has been promising an affordable electric vehicle, likely priced at $25,000, as a way to broaden the appeal of plug-in vehicles.\nHe first mentioned it in a 2018 interview with YouTuber Marques Brownlee, saying \u201ca $25,000 car, that\u2019s something we can do.\u201d Then in 2020, at the company\u2019s first Battery Day event, he speculated that Tesla could eventually produce upward of 20 million of these vehicles in a year \u2014 or roughly twice the current production of Toyota, GM, or Volkswagen.\nThings started to accelerate last year at Tesla\u2019s shareholder event, where the company\u2019s executives spoke about a specialized manufacturing technique that they called the \u201cUnboxed Process.\u201d This breakthrough would allow Tesla to dramatically reduce the cost of manufacturing, enabling it to sell a vehicle at the $25,000 price point.\nThe next-gen vehicle will likely be a crossover or hatchback and could feature design elements lifted from the Tesla Cybertruck.\nBut moreover, it would be the fulfillment of a promise made years ago to make EVs more affordable to the masses.",
#             "Sentiment": "Positive",
#             "Topics": [
#                 "Tesla",
#                 "CEO",
#                 "Elon"
#             ]
#         },
#         {
#             "Title": "Plummeting stock, boycotts and flagging sales: What's fueling turmoil for Tesla?",
#             "Summary": "Tesla is now facing intense competition from other Chinese EV makers, including BYD.\nOn Friday, Reuters reported Tesla was planning to sell a Model Y costing at least 20% less to produce to defend its China share.\nThis week, Trump promised he would purchase a Tesla in a showy presentation on the White House lawn, seemingly further cementing the Trump-Musk alliance.\nFor all the oxygen Musk has taken up with his political activities, concerns about Tesla products themselves are equally keeping investors and analysts up at night.\nMeanwhile, Musk decided to kill Tesla\u2019s cheaper, $25,000 model while going all-in on the Cybertruck, whose sales have yet to take off, Lambert said.",
#             "Sentiment": "Neutral",
#             "Topics": [
#                 "BYD",
#                 "Tesla",
#                 "Chinese"
#             ]
#         },
#         {
#             "Title": "Latest Tesla News",
#             "Summary": "Tesla excluded from incentives in Canada over Trump tariffsTesla has been excluded from two Canadian EV incentive programs, as the country's officials grapple with tariffs from the Trump administration.",
#             "Sentiment": "Neutral",
#             "Topics": [
#                 "Trump",
#                 "excluded",
#                 "Canada"
#             ]
#         },
#         {
#             "Title": "Tesla board members, executive sell off over $100 million of stock in recent weeks",
#             "Summary": "Together, four top officers at the company have offloaded over $100 million in shares since early February.\nBut the recent sales come at a tumultuous time for Tesla, with the stock falling nearly 50% from a peak in mid-December.\nTesla Cybertrucks are seen parked at a dealership, on March 12, 2025, in Plano, Texas.\nSeth Goldstein, an analyst at research firm Morningstar who studies the electric vehicle industry, said some of the stock sales may owe to personal financial choices made by individual officers.\nTesla Chief Financial officer Vaibhav Taneja also sold off shares totaling more than $5 million over recent weeks.",
#             "Sentiment": "Neutral",
#             "Topics": [
#                 "February",
#                 "Tesla",
#                 "million"
#             ]
#         },
#         {
#             "Title": "Hundreds gather outside Tesla showrooms in backlash to Elon Musk\u2019s role with DOGE",
#             "Summary": "The demonstrations are part of the \u201cTesla Takedown\u201d movement, a boycott that began on February 15 against Musk\u2019s electric vehicle company.\nMore than 80 demonstrations are slated for Saturday and more than 70 are planned through the end of April, according to the Tesla Takedown website.\nIn the Boston suburb of Dedham, about 100 demonstrators gathered outside a Tesla showroom.\nBondi said Friday she had opened an investigation into vandalism against Tesla vehicles and showrooms.\nKnutson said Tesla Takedown is not against Tesla drivers or the cars themselves.",
#             "Sentiment": "Positive",
#             "Topics": [
#                 "Tesla",
#                 "Takedown",
#                 "February"
#             ]
#         }
#     ]
# }
# sh: line 1: start: command not found

# %%
import requests
from bs4 import BeautifulSoup
from newspaper import Article, Config
import time
import re
import json
from textblob import TextBlob
import yake
from gtts import gTTS
from deep_translator import GoogleTranslator

class NewsAnalyzer:
    def __init__(self, company_name: str):
        self.company_name = company_name
        self.articles = []
        self.summarized_articles = []
        self.combined_summary = ""
        self.config = Config()
        self.config.request_timeout = 10
        self.config.browser_user_agent = (
            "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
            "AppleWebKit/537.36 (KHTML, like Gecko) "
            "Chrome/89.0.4389.82 Safari/537.36"
        )
        self.kw_extractor = yake.KeywordExtractor(lan="en", n=1, top=5)

    def scrape_and_analyze(self):
        """Main method to perform complete workflow"""
        self._scrape_articles()
        self._process_articles()
        return self._generate_final_report()

    def _scrape_articles(self):
        """Scrape news articles from DuckDuckGo"""
        search_url = "https://duckduckgo.com/html/"
        params = {"q": f"{self.company_name} news", "kl": "us-en"}
        headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"}

        try:
            response = requests.get(search_url, headers=headers, params=params)
            soup = BeautifulSoup(response.text, 'html.parser')
            urls = set()

            for link in soup.select("a.result__a"):
                if href := link.get("href", ""):
                    if match := re.search(r"uddg=(https?://[^&]+)", href):
                        decoded_url = requests.utils.unquote(match.group(1))
                        urls.add(decoded_url)

            for url in list(urls)[:5]:  # Limit to 5 articles for summary
                article = Article(url, config=self.config)
                try:
                    article.download()
                    article.parse()
                    article.nlp()
                    self.articles.append({
                        "title": article.title,
                        "summary": article.summary,
                        "text": article.text,
                        "url": url
                    })
                    time.sleep(1)
                except Exception as e:
                    print(f"Error processing {url}: {str(e)}")

        except Exception as e:
            print(f"Search failed: {str(e)}")

    def _process_articles(self):
        """Create combined summary and analyze sentiment"""
        all_summaries = [article["summary"] for article in self.articles]
        self.combined_summary = "\n".join(all_summaries)
        
        # Extract main keywords from combined text
        keywords = self.kw_extractor.extract_keywords(self.combined_summary)
        self.main_keywords = [kw[0] for kw in keywords[:3]]  # Top 3 keywords

        # Calculate overall sentiment
        blob = TextBlob(self.combined_summary)
        self.sentiment_score = blob.sentiment.polarity

    def _generate_hindi_summary(self):
        """Generate translated summary and audio"""
        try:
            # Create concise English summary
            english_summary = (
                f"Latest news about {self.company_name} covers: "
                f"{', '.join(self.main_keywords)}. "
                f"Overall sentiment is {'positive' if self.sentiment_score > 0 else 'negative' if self.sentiment_score < 0 else 'neutral'}."
            )
            
            # Translate to Hindi
            hindi_text = GoogleTranslator(source='auto', target='hi').translate(english_summary)
            
            # Generate audio
            tts = gTTS(hindi_text, lang='hi')
            audio_file = f"{self.company_name}_hindi_summary.mp3"
            tts.save(audio_file)
            
            return english_summary, hindi_text, audio_file
            
        except Exception as e:
            print(f"Translation error: {str(e)}")
            return "", "", ""

    def _generate_final_report(self):
        """Generate comprehensive report with translations"""
        english_summary, hindi_summary, audio_file = self._generate_hindi_summary()

        return {
            "company": self.company_name,
            "english_summary": english_summary,
            "hindi_summary": hindi_summary,
            "audio_file": audio_file,
            "sentiment_score": self.sentiment_score,
            "main_keywords": self.main_keywords,
            "articles": [{
                "title": article["title"],
                "url": article["url"],
                "summary": article["summary"]
            } for article in self.articles]
        }

# Usage example
if __name__ == "__main__":
    analyzer = NewsAnalyzer("Apple")
    report = analyzer.scrape_and_analyze()
    
    print("\nEnglish Summary:")
    print(report["english_summary"])
    
    print("\nHindi Summary:")
    print(report["hindi_summary"])
    
    print("\nAudio File:", report["audio_file"])
    print("\nMain Keywords:", report["main_keywords"])
    print(f"\nSentiment Score: {report['sentiment_score']:.2f}")
    
    # Play audio file
    import os
    if os.path.exists(report["audio_file"]):
        os.system(f"start {report['audio_file']}")
# Out:
# English Summary:
# Latest news about Apple covers: . Overall sentiment is neutral.
#
# Hindi Summary:
# Apple कवर के बारे में नवीनतम समाचार: कुल मिलाकर भावना तटस्थ है।
#
# Audio File: Apple_hindi_summary.mp3
#
# Main Keywords: []
#
# Sentiment Score: 0.00
# sh: line 1: start: command not found

# %%
analyzer = NewsAnalyzer("CompanyName")
report = analyzer.scrape_and_analyze()

# Access results:
print(report["english_summary"])  # Combined English summary
print(report["hindi_summary"])    # Hindi translation
print(report["audio_file"])       # Path to Hindi audio file
# Out:
# Latest news about CompanyName covers: . Overall sentiment is neutral.
# CompanyName कवर के बारे में नवीनतम समाचार: कुल मिलाकर भावना तटस्थ है।
# CompanyName_hindi_summary.mp3
